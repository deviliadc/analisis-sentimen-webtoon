# %%
pip install google-play-scraper pandas

# %% [markdown]
# # SCRAPING

# %%
from google_play_scraper import reviews
import pandas as pd

# Mengambil ulasan dari Google Play
result, continuation_token = reviews(
    'com.naver.linewebtoon',  # ID aplikasi
    lang='id',           # Ulasan dalam bahasa Indonesia
    count=15000           # Jumlah ulasan yang ingin diambil
)

# Memproses hasil ulasan menjadi DataFrame pandas
reviews_data = pd.DataFrame(result)

# Menyimpan DataFrame ke file CSV
reviews_data.to_csv('/content/drive/MyDrive/Colab Notebooks/dicoding/ulasan.csv', index=False, encoding='utf-8')

print("Ulasan berhasil disimpan ke ulasan.csv")
# Out:
# Ulasan berhasil disimpan ke ulasan.csv

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/dicoding/ulasan.csv')

data
# Out:
#                                    reviewId         userName  \
# 0      e6e83e76-4c4e-4a87-91c7-83a55f7b1454  Pengguna Google
# 1      96c0b35a-4356-4a20-9c74-e7a56c6e34cd  Pengguna Google
# 2      dc400802-14c8-4ddf-b7bf-18c752257d63  Pengguna Google
# 3      22715689-6e53-4340-8bbb-8c4c66daf0f3  Pengguna Google
# 4      c9e2e9ea-82a7-476e-8af3-6b9e4286d029  Pengguna Google
# ...                                     ...              ...
# 14995  a3882e3b-db86-4e01-aef7-dbf4f62c40ea       Sri Rahayu
# 14996  c27ec114-c790-4cee-bec5-876bd5f10132          NazarAE
# 14997  6994b224-012d-430c-8c81-e0917f2c60cc       Cah Belink
# 14998  7f0b4d4c-8c70-42ac-9a3d-aad27dd50168     khairul Adha
# 14999  fc9eefef-b462-4a93-9182-55020048fa6a       Nopri Anto
#
#                                                                                                                       userImage  \
# ...
